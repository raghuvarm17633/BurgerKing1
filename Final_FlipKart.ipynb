# %% [markdown]
# <a href="https://colab.research.google.com/github/raghuvarm17633/BurgerKing1/blob/main/Final_FlipKart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
data = pd.read_csv('Products_dataset.csv')
data
# Out:
#                                            product_name  product_price  Rate  \
# 0     Candes 12 L Room/Personal Air Cooler??????(Whi...           3999     5
# 1     Candes 12 L Room/Personal Air Cooler??????(Whi...           3999     5
# 2     Candes 12 L Room/Personal Air Cooler??????(Whi...           3999     3
# 3     Candes 12 L Room/Personal Air Cooler??????(Whi...           3999     1
# 4     Candes 12 L Room/Personal Air Cooler??????(Whi...           3999     3
# ...                                                 ...            ...   ...
# 2605  cello Pack of 18 Opalware Cello Dazzle Lush Fi...           1299     4
# 2606  cello Pack of 18 Opalware Cello Dazzle Lush Fi...           1299     4
# 2607  cello Pack of 18 Opalware Cello Dazzle Lush Fi...           1299     5
# 2608  cello Pack of 18 Opalware Cello Dazzle Lush Fi...           1299     5
# 2609  cello Pack of 18 Opalware Cello Dazzle Lush Fi...           1299     4
#
# ...

# %%
data2 = data.fillna(data.mean())
data2
# Out:
# <ipython-input-5-142a0a6c0c11>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data2 = data.fillna(data.mean())
#                                            product_name  product_price  Rate  \
# 0     Candes 12 L Room/Personal Air Cooler??????(Whi...           3999     5
# 1     Candes 12 L Room/Personal Air Cooler??????(Whi...           3999     5
# 2     Candes 12 L Room/Personal Air Cooler??????(Whi...           3999     3
# 3     Candes 12 L Room/Personal Air Cooler??????(Whi...           3999     1
# 4     Candes 12 L Room/Personal Air Cooler??????(Whi...           3999     3
# ...                                                 ...            ...   ...
# 2605  cello Pack of 18 Opalware Cello Dazzle Lush Fi...           1299     4
# ...

# %%
data2 = data.fillna(data.mode())
data2
# Out:
#                                            product_name  product_price  Rate  \
# 0     Candes 12 L Room/Personal Air Cooler??????(Whi...           3999     5
# 1     Candes 12 L Room/Personal Air Cooler??????(Whi...           3999     5
# 2     Candes 12 L Room/Personal Air Cooler??????(Whi...           3999     3
# 3     Candes 12 L Room/Personal Air Cooler??????(Whi...           3999     1
# 4     Candes 12 L Room/Personal Air Cooler??????(Whi...           3999     3
# ...                                                 ...            ...   ...
# 2605  cello Pack of 18 Opalware Cello Dazzle Lush Fi...           1299     4
# 2606  cello Pack of 18 Opalware Cello Dazzle Lush Fi...           1299     4
# 2607  cello Pack of 18 Opalware Cello Dazzle Lush Fi...           1299     5
# 2608  cello Pack of 18 Opalware Cello Dazzle Lush Fi...           1299     5
# 2609  cello Pack of 18 Opalware Cello Dazzle Lush Fi...           1299     4
#
# ...

# %%
len(data)
# Out:
# 2610

# %%
data.Sentiment.value_counts()
# Out:
# positive    1955
# negative     503
# neutral      152
# Name: Sentiment, dtype: int64

# %%
data.Summary[0]
# Out:
# 'great cooler excellent air flow and for this price its so amazing and unbelievablejust love it'

# %%
data.product_price.unique()
# Out:
# array([ 3999,  8999,  7999,  9999,  1199,  1999,  1099,   997,  1499,
#          499,  1349, 30999, 13999,  7599, 11999,   329,   425, 44490,
#        52990, 29990,  1401,   209,   219,   549,  1142,  1599,  2454,
#         6099,   849,   699,  2879,  1799,  5390, 11500,  4319,  3499,
#          690,   799,   999,   749,   185,   188,   125,  5993,   988,
#          150,  2152,   361,   449,   275,   200,   199,   198,   645,
#          365,   299,   386,   354,   559,  1169,   409,  6499,  6299,
#         5499,    79,   109,    59,   260,   231, 58990, 63600,  3595,
#        59990,   113,   216,   240,  1278,   349, 66990, 33990, 63990,
#        86990, 46999, 46990, 38990,  2709,  2099,  2999,  2299,  1899,
#          343,   649,  1299,   399,   269,   155,   284,   127,   210,
#          278,  7499,  2499,  1149,   852,   615,   912,   421,   809,
#          789,   489,   669, 24490,   348,   945,   315,   369,   899,
# ...

# %%
data['price_category'] = pd.cut(data.product_price, bins = [0, 10000, 50000, 100000], labels = ['low_spend', 'medium_spend', 'high_spend'])

# %%
# Sentiment counts per product price category sns.countplot(data = data, x = 'Sentiment', hue = 'price_category').set(title='Sentiment counts per product price category') # Medium spend category has majority positive reviews

# %%
print(data.isnull().sum())
# Out:
# product_name        0
# product_price       0
# Rate                0
# Review            102
# Summary             0
# Sentiment           0
# price_category      0
# dtype: int64

# %%
import nltk
import re
nltk.download('stopwords')
stemmer = nltk.SnowballStemmer("english")
from nltk.corpus import stopwords
import string
stopword=set(stopwords.words('english'))

def clean(text):
    text = str(text).lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = [word for word in text.split(' ') if word not in stopword]
    text=" ".join(text)
    text = [stemmer.stem(word) for word in text.split(' ')]
    text=" ".join(text)
    return text
data["Review"] = data["Review"].apply(clean)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
def.shape
# Out:
#   File "<ipython-input-29-26fba82b9f2a>", line 1
#     def.shape
#        ^
# SyntaxError: invalid syntax
